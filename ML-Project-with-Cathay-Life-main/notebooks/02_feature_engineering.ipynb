# %% [markdown]
# # Feature Engineering
#
# This notebook applies feature engineering steps using our modular code:
#
# - Encoding categorical variables
# - Feature scaling (standardization, normalization)
# - Creating new features using our modular feature engineering code

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
import sys
import os
import warnings
warnings.filterwarnings('ignore')  # To avoid non-critical warnings
# Add the project root to the Python path
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.append(project_root)

# Import our custom modules
from src.feature_engineering.encoding import encode_features
from src.feature_engineering.feature_engineering import engineer_features
from src.config import FEATURE_CONFIG

# %% [markdown]
# ### Load the cleaned data from notebook 01

# %%
path = '../data/cleaned/heart_2022_cleaned_01.csv'
df = pd.read_csv(path, sep=',', encoding='utf-8')
df.sample(5)
# Out:
#        State     Sex GeneralHealth  PhysicalHealthDays  MentalHealthDays  \
# 184186    MI    Male     Very good                 0.0               2.0
# 119914    IA  Female          Good                 0.0               0.0
# 356784    TX  Female     Very good                 0.0               0.0
# 277698    NC    Male     Very good                 0.0               0.0
# 308782    OR    Male          Poor                 5.0              29.0
#
#                                           LastCheckupTime PhysicalActivities  \
# 184186  Within past 5 years (2 years but less than 5 y...                Yes
# 119914  Within past year (anytime less than 12 months ...                Yes
# 356784  Within past year (anytime less than 12 months ...                 No
# 277698  Within past year (anytime less than 12 months ...                Yes
# 308782  Within past year (anytime less than 12 months ...                 No
#
#         SleepHours  RemovedTeeth  HadHeartAttack  ...    BMI AlcoholDrinkers  \
# 184186         7.0        1 to 5               0  ...  34.18              No
# 119914         7.0        1 to 5               0  ...  27.44              No
# 356784         6.0  None of them               0  ...  33.28             Yes
# 277698         6.0        1 to 5               0  ...  27.99             Yes
# 308782         5.0  None of them               0  ...  23.17             Yes
#
#        HIVTesting FluVaxLast12 PneumoVaxEver  \
# 184186        Yes          Yes            No
# 119914        Yes          Yes            No
# 356784         No          Yes            No
# 277698        Yes          Yes            No
# 308782        Yes           No            No
#
#                                         TetanusLast10Tdap HighRiskLastYear  \
# 184186  Yes, received tetanus shot but not sure what type               No
# 119914  Yes, received tetanus shot but not sure what type               No
# 356784  No, did not receive any tetanus shot in the pa...               No
# 277698  No, did not receive any tetanus shot in the pa...               No
# 308782           Yes, received tetanus shot, but not Tdap               No
#
#        CovidPos   BMI_Category SleepHours_Category
# 184186       No          Obese        Normal Sleep
# 119914      Yes     Overweight        Normal Sleep
# 356784       No          Obese         Short Sleep
# 277698       No     Overweight         Short Sleep
# 308782       No  Normal weight         Short Sleep
#
# [5 rows x 42 columns]

# %% [markdown]
# ### 1. Encoding Categorical Variables

# %%
# Apply encoding
df = encode_features(df)
print("Remaining object (categorical) columns:")
df.describe(include='object').T
# Out:
# Remaining object (categorical) columns:
#                         count unique                       top    freq
# State                  442067     54                        WA   25997
# RaceEthnicityCategory  442067      5  White only, Non-Hispanic  332480

# %% [markdown]
# ### 2. Feature Engineering

# %%
# Apply feature engineering
print("Creating interaction and polynomial features for:", FEATURE_CONFIG['interaction_features'])
df = engineer_features(df)
df.sample(5)
# Out:
# Creating interaction and polynomial features for: ['BMI', 'WeightInKilograms', 'HeightInMeters']
#        State  Sex  GeneralHealth  PhysicalHealthDays  MentalHealthDays  \
# 81293     GA    0              2                 0.0               0.0
# 127346    KS    0              3                 2.0               0.0
# 267825    NY    1              1                 5.0              20.0
# 200012    MN    1              1                30.0               5.0
# 10420     AZ    1              1                 0.0              20.0
#
#         LastCheckupTime  PhysicalActivities  SleepHours  RemovedTeeth  \
# 81293                 3                   1         6.0             0
# 127346                3                   1         9.0             0
# 267825                3                   0         3.0             0
# 200012                2                   0         5.0             2
# 10420                 3                   0         7.0             1
#
#         HadHeartAttack  ...  SleepHours_Category  \
# 81293                0  ...                    1
# 127346               0  ...                    2
# 267825               0  ...                    3
# 200012               0  ...                    1
# 10420                0  ...                    0
#
#         BMI_WeightInKilograms_interaction  BMI_HeightInMeters_interaction  \
# 81293                           1786.0893                         42.1496
# 127346                          2613.6600                         48.0200
# 267825                          9934.1099                         99.6964
# 200012                          3008.4920                         54.9130
# 10420                           7087.8215                         84.2830
#
#         WeightInKilograms_HeightInMeters_interaction  BMI^2_poly  \
# 81293                                        97.9032    768.9529
# 127346                                      166.6875    752.9536
# 267825                                      352.1804   2812.1809
# 200012                                      173.5856    951.7225
# 10420                                       266.4482   2242.0225
#
#         BMI_WeightInKilograms_poly  BMI_HeightInMeters_poly  \
# 81293                    1786.0893                  42.1496
# 127346                   2613.6600                  48.0200
# 267825                   9934.1099                  99.6964
# 200012                   3008.4920                  54.9130
# 10420                    7087.8215                  84.2830
#
#         WeightInKilograms^2_poly  WeightInKilograms_HeightInMeters_poly  \
# 81293                  4148.6481                                97.9032
# 127346                 9072.5625                               166.6875
# 267825                35092.5289                               352.1804
# 200012                 9510.1504                               173.5856
# 10420                 22407.0961                               266.4482
#
#         HeightInMeters^2_poly
# 81293                  2.3104
# 127346                 3.0625
# 267825                 3.5344
# 200012                 3.1684
# 10420                  3.1684
#
# [5 rows x 51 columns]

# %% [markdown]
# ### Rod can paste your work here

# %%
import seaborn as sns


# 定義特徵列表和目標變數
features = df.drop(columns="HadHeartAttack")
target = 'HadHeartAttack'

# 選擇一個主要分類變數作為交互基準
interaction_base = 'AgeCategory'

# 定義連續變數和分類變數
continuous_vars = ['PhysicalHealthDays', 'MentalHealthDays', 'SleepHours', 'HeightInMeters', 'WeightInKilograms', 'BMI']
categorical_vars = [f for f in features if f not in continuous_vars and f != interaction_base]

# 1. 連續變數：散點圖觀察交互作用（與AgeCategory）
for feature in continuous_vars:
    plt.figure(figsize=(10, 6))
    sns.scatterplot(data=df, x=feature, y=target, hue=interaction_base, s=100)
    plt.title(f'Relationship between {feature} and Heart Attack Risk by {interaction_base}', fontsize=14)
    plt.xlabel(feature, fontsize=12)
    plt.ylabel('Had Heart Attack (0 = No, 1 = Yes)', fontsize=12)
    plt.legend(title=interaction_base)
    plt.tight_layout()
    plt.show()

# 2. 分類變數：分組條形圖觀察交互作用（與 AgeCategory）
for feature in categorical_vars:
    plt.figure(figsize=(10, 6))
    # 計算每個組合下的心臟病比例
    grouped = df.groupby([feature, interaction_base])[target].mean().reset_index()
    sns.barplot(data=grouped, x=feature, y=target, hue=interaction_base)
    plt.title(f'Heart Attack Risk by {feature} and {interaction_base}', fontsize=14)
    plt.xlabel(feature, fontsize=12)
    plt.ylabel('Proportion of Heart Attack (0-1)', fontsize=12)
    plt.xticks(rotation=45, ha='right')
    plt.legend(title=interaction_base)
    plt.tight_layout()
    plt.show()

# %%
# there are related paper to support these
df["Sex_Age"] = df["Sex"] * df["AgeCategory"]
df["Weight_MentalHealthDays"] = df["WeightInKilograms"] * df["MentalHealthDays"]
df["Sex_Diabetes"] = df["Sex"] * df["HadDiabetes"]
df["AgeCategory_Diabetes"] = df["AgeCategory"] * df["HadDiabetes"]
df["BMI_Age"] = df["BMI"] * df["AgeCategory"] 
df["BMI_SleepHours"] = df["BMI"] * df["SleepHours"] 
df["SmokerStatus_Sex"] = df["SmokerStatus"] * df["Sex"]
df["SmokerStatus_Age"] = df["SmokerStatus"] * df["AgeCategory"]
df["PhysicalActivities_AgeCategory"] = df["PhysicalActivities"] * df["AgeCategory"]
df["PhysicalActivities_AgeCategory"] = df["PhysicalActivities"] * df["AgeCategory"]
df["AgeCategory_HadStroke"] = df["AgeCategory"] * df["HadStroke"]
df["Age_Ethnicity"] = df["AgeCategory"] * df["RaceEthnicityCategory"]

# %% [markdown]
# ### 3. Feature Scaling

# %%
# Get numerical columns
numerical_columns = df.select_dtypes(include=['float64']).columns.tolist()

# %%
# Apply StandardScaler to the numerical columns
scaler = StandardScaler()
df[numerical_columns] = scaler.fit_transform(df[numerical_columns])

df.sample(5)
# Out:
#        State  Sex  GeneralHealth  PhysicalHealthDays  MentalHealthDays  \
# 95093     ID    1              2            3.003572         -0.515488
# 245432    NJ    0              3           -0.491530         -0.515488
# 191920    MN    1              2           -0.491530         -0.515488
# 295782    OH    1              2           -0.491530          1.890823
# 49848     CT    0              3           -0.142020         -0.395172
#
#         LastCheckupTime  PhysicalActivities  SleepHours  RemovedTeeth  \
# 95093                 3                   1    0.656772             1
# 245432                3                   1   -0.687687             1
# 191920                3                   1    0.656772             0
# 295782                1                   1   -0.015457             0
# 49848                 3                   1    0.656772             0
#
#         HadHeartAttack  ...  SleepHours_Category  \
# 95093                0  ...                    0
# 245432               0  ...                    1
# 191920               0  ...                    0
# 295782               0  ...                    0
# 49848                0  ...                    0
#
#         BMI_WeightInKilograms_interaction  BMI_HeightInMeters_interaction  \
# 95093                            1.528528                        1.611651
# 245432                          -0.104917                       -0.002327
# 191920                          -0.430830                       -0.409767
# 295782                          -0.073458                        0.041618
# 49848                           -1.097478                       -1.367030
#
#         WeightInKilograms_HeightInMeters_interaction  BMI^2_poly  \
# 95093                                       2.581372    0.753741
# 245432                                     -0.652066    0.302309
# 191920                                     -0.177782   -0.513906
# 295782                                     -0.121954   -0.003703
# 49848                                      -1.335204   -1.004447
#
#         BMI_WeightInKilograms_poly  BMI_HeightInMeters_poly  \
# 95093                     1.528528                 1.611651
# 245432                   -0.104917                -0.002327
# 191920                   -0.430830                -0.409767
# 295782                   -0.073458                 0.041618
# 49848                    -1.097478                -1.367030
#
#         WeightInKilograms^2_poly  WeightInKilograms_HeightInMeters_poly  \
# 95093                   2.236352                               2.581372
# 245432                 -0.424933                              -0.652066
# 191920                 -0.337763                              -0.177782
# 295782                 -0.155609                              -0.121954
# 49848                  -1.091714                              -1.335204
#
#         HeightInMeters^2_poly
# 95093                2.304482
# 245432              -1.433055
# 191920               0.432322
# 295782              -0.246279
# 49848               -0.714037
#
# [5 rows x 51 columns]

# %% [markdown]
# ### 4. Save the Engineered Dataset

# %%
output_path = '../data/cleaned/heart_2022_cleaned_02.csv'
df.to_csv(output_path, index=False)
print(f"Saved engineered dataset to {output_path}")
# Out:
# Saved engineered dataset to ../data/cleaned/heart_2022_cleaned_02.csv
